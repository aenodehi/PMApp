# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Nasa/archive.zip -d /content/drive/MyDrive/Nasa/
# Out:
# Archive:  /content/drive/MyDrive/Nasa/archive.zip
#   inflating: /content/drive/MyDrive/Nasa/PdM_errors.csv
#   inflating: /content/drive/MyDrive/Nasa/PdM_failures.csv
#   inflating: /content/drive/MyDrive/Nasa/PdM_machines.csv
#   inflating: /content/drive/MyDrive/Nasa/PdM_maint.csv
#   inflating: /content/drive/MyDrive/Nasa/PdM_telemetry.csv

# %%
import pandas as pd

pdm_errors = pd.read_csv('/content/drive/MyDrive/Nasa/PdM_errors.csv')
pdm_errors.head()
# Out:
#               datetime  machineID errorID
# 0  2015-01-03 07:00:00          1  error1
# 1  2015-01-03 20:00:00          1  error3
# 2  2015-01-04 06:00:00          1  error5
# 3  2015-01-10 15:00:00          1  error4
# 4  2015-01-22 10:00:00          1  error4

# %%
len(pdm_errors)
# Out:
# 3919

# %%
PdM_failures = pd.read_csv('/content/drive/MyDrive/Nasa/PdM_failures.csv')
PdM_failures.head()
# Out:
#               datetime  machineID failure
# 0  2015-01-05 06:00:00          1   comp4
# 1  2015-03-06 06:00:00          1   comp1
# 2  2015-04-20 06:00:00          1   comp2
# 3  2015-06-19 06:00:00          1   comp4
# 4  2015-09-02 06:00:00          1   comp4

# %%
len(PdM_failures)
# Out:
# 761

# %%
pdM_machines = pd.read_csv('/content/drive/MyDrive/Nasa/PdM_machines.csv')
pdM_machines.head()
# Out:
#    machineID   model  age
# 0          1  model3   18
# 1          2  model4    7
# 2          3  model3    8
# 3          4  model3    7
# 4          5  model3    2

# %%
pdM_maint = pd.read_csv('/content/drive/MyDrive/Nasa/PdM_maint.csv')
pdM_maint.head()
# Out:
#               datetime  machineID   comp
# 0  2014-06-01 06:00:00          1  comp2
# 1  2014-07-16 06:00:00          1  comp4
# 2  2014-07-31 06:00:00          1  comp3
# 3  2014-12-13 06:00:00          1  comp1
# 4  2015-01-05 06:00:00          1  comp4

# %%
len(pdM_maint)
# Out:
# 3286

# %%
PdM_telemetry = pd.read_csv('/content/drive/MyDrive/Nasa/PdM_telemetry.csv')
PdM_telemetry.head()
# Out:
#               datetime  machineID        volt      rotate    pressure  \
# 0  2015-01-01 06:00:00          1  176.217853  418.504078  113.077935
# 1  2015-01-01 07:00:00          1  162.879223  402.747490   95.460525
# 2  2015-01-01 08:00:00          1  170.989902  527.349825   75.237905
# 3  2015-01-01 09:00:00          1  162.462833  346.149335  109.248561
# 4  2015-01-01 10:00:00          1  157.610021  435.376873  111.886648
#
#    vibration
# 0  45.087686
# 1  43.413973
# 2  34.178847
# 3  41.122144
# 4  25.990511

# %%
len(PdM_telemetry)
# Out:
# 876100

# %%
result = pd.merge(PdM_telemetry, pdM_machines, on='machineID', how='inner')

# %%
result.head()
# Out:
#               datetime  machineID        volt      rotate    pressure  \
# 0  2015-01-01 06:00:00          1  176.217853  418.504078  113.077935
# 1  2015-01-01 07:00:00          1  162.879223  402.747490   95.460525
# 2  2015-01-01 08:00:00          1  170.989902  527.349825   75.237905
# 3  2015-01-01 09:00:00          1  162.462833  346.149335  109.248561
# 4  2015-01-01 10:00:00          1  157.610021  435.376873  111.886648
#
#    vibration   model  age
# 0  45.087686  model3   18
# 1  43.413973  model3   18
# 2  34.178847  model3   18
# 3  41.122144  model3   18
# 4  25.990511  model3   18

# %%
len(result)
# Out:
# 876100

# %%
result = pd.merge(result, PdM_failures, on=['machineID','datetime'], how='inner')
result.head()
# result = pd.merge(result, pdM_machines, on=['machineID','datetime'], how='inner')
# Out:
#               datetime  machineID        volt      rotate    pressure  \
# 0  2015-01-05 06:00:00          1  179.303153  499.777962  111.833028
# 1  2015-03-06 06:00:00          1  198.257975  456.862342   89.333995
# 2  2015-04-20 06:00:00          1  180.050801  346.362480  105.661164
# 3  2015-06-19 06:00:00          1  187.673963  493.005160  105.334392
# 4  2015-09-02 06:00:00          1  144.094532  409.380150  106.720871
#
#    vibration   model  age failure
# 0  52.383097  model3   18   comp4
# 1  38.671900  model3   18   comp1
# 2  39.218055  model3   18   comp2
# 3  53.963961  model3   18   comp4
# 4  57.454990  model3   18   comp4

# %%
len(result)
# Out:
# 761
